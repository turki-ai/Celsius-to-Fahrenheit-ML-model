# %%
dic = {
    'input': [0, 8 , 15, 22],
    'output': [32, 46.4, 59, 71.6]
}

# %%
import pandas as pd
df = pd.DataFrame(dic)
df
# Out:
#    input  output
# 0      0    32.0
# 1      8    46.4
# 2     15    59.0
# 3     22    71.6

# %%
x = df['input']
y= df['output']

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import warnings
warnings.filterwarnings('ignore')

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential

model = Sequential([
    Dense(1, input_shape=(1,), activation = 'linear')
])

# %%
model.compile(
    loss = 'mse',
    metrics = ['mae'],
    optimizer = Adam()
)

# %%
m = model.fit(
    x= x,
    y = y,
    epochs= 50000
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8 (36.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6 (28.00 B)

# %%
print('loss:', m.history['loss'][-1])
# Out:
# loss: 1.1248630471527576e-08

# %%
print('MAE:', m.history['mae'][-1])
# Out:
# MAE: 8.58306884765625e-05

# %%
import numpy as np
print(model.predict(np.array([30])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [[86.00009]]

# %%
print(model.predict(np.array([58])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [[136.40018]]

# %%
print(model.predict(np.array([13])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [[55.40004]]

# %%
print(model.predict(np.array([22])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [[71.60007]]
